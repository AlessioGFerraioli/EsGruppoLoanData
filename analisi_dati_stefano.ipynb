# %% [markdown]
# Scoprite Kaggle e confrontatevi sulla piattaforma, vi invito ad esplorarla per bene in quanto punto di riferimento per il machine learning e ai moderna
#
# kaggle.com
#
# Provare ad analizzare tutti insieme un nuovo set di dati:
#
# https://www.kaggle.com/competitions/playground-series-s4e10/code
#
# C’è anche una sezione con I risultati di alcuni utenti e il loro codice, provate a scoprire se ci sono dei passaggi interessati per quanto riguarda l’analisi e aggiungeteli al vostro foglio con le funzioni di analisi
#
# Sempre prendendo spunto dai risultati di altri utenti provarte a creare un modello di machine learning e a mettere il risultato dell’analisi su kaggle… vi restituirà un punteggio in base al quale verrete posizionati in una classifica sull’argomento
#
# Inviare un solo file jupyter (rappresentativo della classe) con codice, analisi e commento sempre a mbagnoli999@gmail.com

# %%
import math
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

df = pd.read_csv('train.csv')

print("\nInformazioni Data Frame\n\n")

display(df.info())
# Out:
# Informazioni Data Frame
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          58645 non-null  int64
#  1   person_age                  58645 non-null  int64
#  2   person_income               58645 non-null  int64
#  3   person_home_ownership       58645 non-null  object
#  4   person_emp_length           58645 non-null  float64
#  5   loan_intent                 58645 non-null  object
#  6   loan_grade                  58645 non-null  object
#  7   loan_amnt                   58645 non-null  int64
#  8   loan_int_rate               58645 non-null  float64
#  9   loan_percent_income         58645 non-null  float64
#  10  cb_person_default_on_file   58645 non-null  object
#  11  cb_person_cred_hist_length  58645 non-null  int64
#  12  loan_status                 58645 non-null  int64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 5.8+ MB
# None

# %%
df.describe()
# Out:
#                  id    person_age  person_income  person_emp_length  \
# count  58645.000000  58645.000000   5.864500e+04       58645.000000
# mean   29322.000000     27.550857   6.404617e+04           4.701015
# std    16929.497605      6.033216   3.793111e+04           3.959784
# min        0.000000     20.000000   4.200000e+03           0.000000
# 25%    14661.000000     23.000000   4.200000e+04           2.000000
# 50%    29322.000000     26.000000   5.800000e+04           4.000000
# 75%    43983.000000     30.000000   7.560000e+04           7.000000
# max    58644.000000    123.000000   1.900000e+06         123.000000
#
#           loan_amnt  loan_int_rate  loan_percent_income  \
# count  58645.000000   58645.000000         58645.000000
# mean    9217.556518      10.677874             0.159238
# std     5563.807384       3.034697             0.091692
# min      500.000000       5.420000             0.000000
# 25%     5000.000000       7.880000             0.090000
# 50%     8000.000000      10.750000             0.140000
# 75%    12000.000000      12.990000             0.210000
# max    35000.000000      23.220000             0.830000
#
#        cb_person_cred_hist_length   loan_status
# count                58645.000000  58645.000000
# mean                     5.813556      0.142382
# std                      4.029196      0.349445
# min                      2.000000      0.000000
# 25%                      3.000000      0.000000
# 50%                      4.000000      0.000000
# 75%                      8.000000      0.000000
# max                     30.000000      1.000000

# %%
df.isnull().sum()
# Out:
# id                            0
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# loan_status                   0
# dtype: int64

# %%
df[df["cb_person_default_on_file"]== "Y"]["cb_person_default_on_file"].count()

df[df["cb_person_default_on_file"]== "N"]["cb_person_default_on_file"].count()

df[df["cb_person_cred_hist_length"] == 2]["cb_person_cred_hist_length"].count()
# Out:
# np.int64(10657)

# %%
#Neumerical Columns
num_col = df.select_dtypes(exclude='object').columns
#Categorical Columns
cat_col = df.select_dtypes(include='object').columns

# %%
#For neumeric feature
fig,axes = plt.subplots(math.ceil(len(num_col.values)/2),2,figsize=(14,14))
plt.subplots_adjust(hspace=0.5)

#Plot the histogram for all neumeric columns

for idx, col in enumerate(num_col):
    x = idx//2
    y = idx%2
    sns.histplot(df[col],kde=True,ax=axes[x,y])
    axes[x, y].set_title(f'Distribution of {col}')
    axes[x, y].set_xlabel(col)
    axes[x, y].set_ylabel('Count')
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_default_on_file',
#        'cb_person_cred_hist_length', 'loan_status'],
#       dtype='object')

# %%
#['person_home_ownership', 'loan_intent', 'loan_grade', 'cb_person_default_on_file']

for el in ['person_home_ownership', 'loan_intent', 'loan_grade', 'cb_person_default_on_file']:
    print("el: ", df[el].nunique())
# Out:
# el:  4
# el:  6
# el:  7
# el:  2

# %%
#Proviamo a modificare la funzione di ieri:

def analyze_and_plot_fixed(dataframe, group_col, base_path):
    # Lista per DataFrame filtrati e correlazioni
    filtered_corr_list = []
    
    # Valori unici della colonna
    unique_values = dataframe[group_col].unique()
    
    for value in unique_values:
        # Filtra il DataFrame
        df_filtered = dataframe[dataframe[group_col] == value]
        
        if df_filtered.empty:
            continue  # Salta se il DataFrame è vuoto
        
        # Nome del gruppo
        group_name = str(df_filtered[group_col].iloc[0]).replace("/", "-")  # Gestione di caratteri speciali
        
        # Rimuovi le colonne non necessarie
        df_cleaned = df_filtered.drop(['person_home_ownership', 'loan_intent', 'loan_grade', 'cb_person_default_on_file'], axis=1, errors='ignore')
        
        # Calcola la matrice di correlazione
        corr_matrix = df_cleaned.corr()
        
        # Filtra correlazioni significative
        filtered = corr_matrix.where(((corr_matrix > 0.3) | (corr_matrix < -0.3)) & (corr_matrix != 1)).stack()
        filtered_corr_list.append((f'{group_col} name: {group_name}\n', filtered))
        
        # Crea la directory per salvare le immagini
        save_path = os.path.join(base_path, group_col)
        os.makedirs(save_path, exist_ok=True)
        
        # Plotta la heatmap
        plt.figure(figsize=(10, 8))
        sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
        plt.title(f'Heatmap for {group_col}: {group_name}')
        
        # Salva il grafico
        plt.savefig(f'{save_path}/{group_name}_heatmap.png', bbox_inches='tight')
        plt.close()  # Chiudi il grafico per evitare conflitti
        
    return filtered_corr_list


base_path = './image'
filtered_corr_home_own = analyze_and_plot_fixed(df, 'person_home_ownership', base_path)
filtered_corr_loan_intent = analyze_and_plot_fixed(df, 'loan_intent', base_path)
#['person_home_ownership', 'loan_intent', 'loan_grade', 'cb_person_default_on_file']
filtered_corr_loan_grade = analyze_and_plot_fixed(df, 'loan_grade', base_path)
filtered_corr_cb_default = analyze_and_plot_fixed(df, 'cb_person_default_on_file', base_path)

# %%
corr_filtrate = [filtered_corr_home_own, filtered_corr_loan_intent, filtered_corr_loan_grade, filtered_corr_cb_default]
for el in corr_filtrate:
    display(el)
# Out:
# [('person_home_ownership name: RENT\n',
#   person_age                  cb_person_cred_hist_length    0.880210
#   person_income               loan_amnt                     0.323939
#   loan_amnt                   person_income                 0.323939
#                               loan_percent_income           0.682919
#   loan_int_rate               loan_status                   0.335683
#   loan_percent_income         loan_amnt                     0.682919
#                               loan_status                   0.478472
#   cb_person_cred_hist_length  person_age                    0.880210
#   loan_status                 loan_int_rate                 0.335683
#                               loan_percent_income           0.478472
#   dtype: float64),
#  ('person_home_ownership name: OWN\n',
#   person_age                  cb_person_cred_hist_length    0.876507
#   person_income               loan_amnt                     0.327054
#   loan_amnt                   person_income                 0.327054
#                               loan_percent_income           0.612440
#   loan_percent_income         loan_amnt                     0.612440
#   cb_person_cred_hist_length  person_age                    0.876507
#   dtype: float64),
#  ('person_home_ownership name: MORTGAGE\n',
#   person_age                  cb_person_cred_hist_length    0.865865
#   loan_amnt                   loan_percent_income           0.699780
#   loan_int_rate               loan_status                   0.312995
#   loan_percent_income         loan_amnt                     0.699780
#   cb_person_cred_hist_length  person_age                    0.865865
#   loan_status                 loan_int_rate                 0.312995
#   dtype: float64),
#  ('person_home_ownership name: OTHER\n',
#   person_age                  person_emp_length             0.423600
#                               cb_person_cred_hist_length    0.883667
#   person_income               loan_amnt                     0.373595
#                               loan_percent_income          -0.386677
#   person_emp_length           person_age                    0.423600
#                               cb_person_cred_hist_length    0.355871
#   loan_amnt                   person_income                 0.373595
#                               loan_percent_income           0.594693
#   loan_int_rate               loan_status                   0.379371
#   loan_percent_income         person_income                -0.386677
#                               loan_amnt                     0.594693
#                               loan_status                   0.400185
#   cb_person_cred_hist_length  person_age                    0.883667
#                               person_emp_length             0.355871
#   loan_status                 loan_int_rate                 0.379371
#                               loan_percent_income           0.400185
#   dtype: float64)]
# [('loan_intent name: EDUCATION\n',
#   person_age                  cb_person_cred_hist_length    0.871835
#   loan_amnt                   loan_percent_income           0.666378
#   loan_percent_income         loan_amnt                     0.666378
#                               loan_status                   0.391602
#   cb_person_cred_hist_length  person_age                    0.871835
#   loan_status                 loan_percent_income           0.391602
#   dtype: float64),
#  ('loan_intent name: MEDICAL\n',
#   person_age                  cb_person_cred_hist_length    0.864460
#   person_income               loan_amnt                     0.345332
#   loan_amnt                   person_income                 0.345332
#                               loan_percent_income           0.635994
#   loan_int_rate               loan_status                   0.425486
#   loan_percent_income         loan_amnt                     0.635994
#                               loan_status                   0.386196
#   cb_person_cred_hist_length  person_age                    0.864460
#   loan_status                 loan_int_rate                 0.425486
#                               loan_percent_income           0.386196
#   dtype: float64),
#  ('loan_intent name: PERSONAL\n',
#   person_age                  cb_person_cred_hist_length    0.894304
#   person_income               loan_amnt                     0.318124
#   loan_amnt                   person_income                 0.318124
#                               loan_percent_income           0.632669
#   loan_percent_income         loan_amnt                     0.632669
#                               loan_status                   0.388957
#   cb_person_cred_hist_length  person_age                    0.894304
#   loan_status                 loan_percent_income           0.388957
#   dtype: float64),
#  ('loan_intent name: VENTURE\n',
#   person_age                  cb_person_cred_hist_length    0.872627
#   loan_amnt                   loan_percent_income           0.647374
#   loan_percent_income         loan_amnt                     0.647374
#                               loan_status                   0.399044
#   cb_person_cred_hist_length  person_age                    0.872627
#   loan_status                 loan_percent_income           0.399044
#   dtype: float64),
#  ('loan_intent name: DEBTCONSOLIDATION\n',
#   person_age                  cb_person_cred_hist_length    0.865183
#   loan_amnt                   loan_percent_income           0.665893
#   loan_int_rate               loan_status                   0.469618
#   loan_percent_income         loan_amnt                     0.665893
#                               loan_status                   0.404049
#   cb_person_cred_hist_length  person_age                    0.865183
#   loan_status                 loan_int_rate                 0.469618
#                               loan_percent_income           0.404049
#   dtype: float64),
#  ('loan_intent name: HOMEIMPROVEMENT\n',
#   person_age                  cb_person_cred_hist_length    0.834836
#   person_income               loan_amnt                     0.312236
#                               loan_percent_income          -0.323647
#   loan_amnt                   person_income                 0.312236
#                               loan_percent_income           0.661351
#   loan_int_rate               loan_status                   0.333494
#   loan_percent_income         person_income                -0.323647
#                               loan_amnt                     0.661351
#   cb_person_cred_hist_length  person_age                    0.834836
#   loan_status                 loan_int_rate                 0.333494
#   dtype: float64)]
# [('loan_grade name: B\n',
#   person_age                  cb_person_cred_hist_length    0.867246
#   person_income               loan_amnt                     0.345566
#   loan_amnt                   person_income                 0.345566
#                               loan_percent_income           0.645358
#   loan_percent_income         loan_amnt                     0.645358
#                               loan_status                   0.425778
#   cb_person_cred_hist_length  person_age                    0.867246
#   loan_status                 loan_percent_income           0.425778
#   dtype: float64),
#  ('loan_grade name: C\n',
#   person_age                  cb_person_cred_hist_length    0.881290
#   person_income               loan_amnt                     0.332421
#   loan_amnt                   person_income                 0.332421
#                               loan_percent_income           0.637176
#   loan_percent_income         loan_amnt                     0.637176
#                               loan_status                   0.385001
#   cb_person_cred_hist_length  person_age                    0.881290
#   loan_status                 loan_percent_income           0.385001
#   dtype: float64),
#  ('loan_grade name: A\n',
#   person_age                  cb_person_cred_hist_length    0.874304
#   person_income               loan_percent_income          -0.327470
#   loan_amnt                   loan_percent_income           0.638105
#   loan_percent_income         person_income                -0.327470
#                               loan_amnt                     0.638105
#                               loan_status                   0.385322
#   cb_person_cred_hist_length  person_age                    0.874304
#   loan_status                 loan_percent_income           0.385322
#   dtype: float64),
#  ('loan_grade name: D\n',
#   person_age                  cb_person_cred_hist_length    0.883475
#   person_income               loan_amnt                     0.339655
#   loan_amnt                   person_income                 0.339655
#                               loan_percent_income           0.643718
#   loan_percent_income         loan_amnt                     0.643718
#   cb_person_cred_hist_length  person_age                    0.883475
#   dtype: float64),
#  ('loan_grade name: E\n',
#   person_age                  cb_person_cred_hist_length    0.875892
#   person_income               loan_amnt                     0.366488
#                               loan_percent_income          -0.340165
#                               loan_status                  -0.420451
#   person_emp_length           loan_status                  -0.301388
#   loan_amnt                   person_income                 0.366488
#                               loan_percent_income           0.621077
#   loan_percent_income         person_income                -0.340165
#                               loan_amnt                     0.621077
#   cb_person_cred_hist_length  person_age                    0.875892
#   loan_status                 person_income                -0.420451
#                               person_emp_length            -0.301388
#   dtype: float64),
#  ('loan_grade name: F\n',
#   person_age                  cb_person_cred_hist_length    0.911835
#   person_income               loan_amnt                     0.446683
#                               loan_percent_income          -0.354534
#                               loan_status                  -0.528473
#   person_emp_length           loan_status                  -0.487398
#   loan_amnt                   person_income                 0.446683
#                               loan_percent_income           0.547493
#   loan_percent_income         person_income                -0.354534
#                               loan_amnt                     0.547493
#   cb_person_cred_hist_length  person_age                    0.911835
#   loan_status                 person_income                -0.528473
#                               person_emp_length            -0.487398
#   dtype: float64),
#  ('loan_grade name: G\n',
#   id                          person_income                -0.377740
#                               loan_percent_income           0.359168
#   person_age                  cb_person_cred_hist_length    0.852505
#   person_income               id                           -0.377740
#                               loan_amnt                     0.395048
#                               loan_int_rate                 0.325179
#                               loan_percent_income          -0.308468
#                               cb_person_cred_hist_length    0.388855
#                               loan_status                  -0.725664
#   loan_amnt                   person_income                 0.395048
#                               loan_percent_income           0.653058
#                               loan_status                  -0.364149
#   loan_int_rate               person_income                 0.325179
#   loan_percent_income         id                            0.359168
#                               person_income                -0.308468
#                               loan_amnt                     0.653058
#   cb_person_cred_hist_length  person_age                    0.852505
#                               person_income                 0.388855
#   loan_status                 person_income                -0.725664
#                               loan_amnt                    -0.364149
#   dtype: float64)]
# [('cb_person_default_on_file name: N\n',
#   person_age                  cb_person_cred_hist_length    0.872540
#   person_income               loan_amnt                     0.308694
#   loan_amnt                   person_income                 0.308694
#                               loan_percent_income           0.645385
#   loan_percent_income         loan_amnt                     0.645385
#                               loan_status                   0.394581
#   cb_person_cred_hist_length  person_age                    0.872540
#   loan_status                 loan_percent_income           0.394581
#   dtype: float64),
#  ('cb_person_default_on_file name: Y\n',
#   person_age                  cb_person_cred_hist_length    0.883738
#   person_income               loan_amnt                     0.330058
#   loan_amnt                   person_income                 0.330058
#                               loan_percent_income           0.656406
#   loan_int_rate               loan_status                   0.357793
#   loan_percent_income         loan_amnt                     0.656406
#                               loan_status                   0.325883
#   cb_person_cred_hist_length  person_age                    0.883738
#   loan_status                 loan_int_rate                 0.357793
#                               loan_percent_income           0.325883
#   dtype: float64)]

# %%
def corr_comuni(filtered_corr_list,nome_lista):

    correlation_dict = {}

    for group_info, filtered_corr in filtered_corr_list:
        group_name = group_info.strip()
        for (col1, col2), value in filtered_corr.items():
            pair = tuple(sorted([col1, col2]))
            correlation_dict.setdefault(pair, set()).add(group_name)

    #Filtra le coppie presenti in almeno 2 elementi unici della colonna
    relevant_correlations = {pair: names for pair, names in correlation_dict.items() if len(names) >= 2}

    #Stampa i risultati
    print(f"Correlazioni presenti in 2 o più {nome_lista}:")
    for pair, names in relevant_correlations.items():
        print(f"{pair}: presenti in {len(names)} {nome_lista} -> {', '.join(names)}")

    return relevant_correlations

#['person_home_ownership', 'loan_intent', 'loan_grade', 'cb_person_default_on_file']
#[filtered_corr_home_own, filtered_corr_loan_intent, filtered_corr_loan_grade, filtered_corr_cb_default]

relevant_correlations_status = corr_comuni(filtered_corr_home_own,"person_home_ownership")
print("\n\n---------------------\n\n")
relevant_correlations_adult = corr_comuni(filtered_corr_loan_intent, "loan_intent")
print("\n\n---------------------\n\n")
relevant_correlations_adult = corr_comuni(filtered_corr_loan_grade, "loan_grade")
print("\n\n---------------------\n\n")
relevant_correlations_adult = corr_comuni(filtered_corr_cb_default, "cb_person_default_on_file")
# Out:
# Correlazioni presenti in 2 o più person_home_ownership:
# ('cb_person_cred_hist_length', 'person_age'): presenti in 4 person_home_ownership -> person_home_ownership name: OTHER, person_home_ownership name: MORTGAGE, person_home_ownership name: RENT, person_home_ownership name: OWN
# ('loan_amnt', 'person_income'): presenti in 3 person_home_ownership -> person_home_ownership name: OTHER, person_home_ownership name: RENT, person_home_ownership name: OWN
# ('loan_amnt', 'loan_percent_income'): presenti in 4 person_home_ownership -> person_home_ownership name: OTHER, person_home_ownership name: MORTGAGE, person_home_ownership name: RENT, person_home_ownership name: OWN
# ('loan_int_rate', 'loan_status'): presenti in 3 person_home_ownership -> person_home_ownership name: MORTGAGE, person_home_ownership name: RENT, person_home_ownership name: OTHER
# ('loan_percent_income', 'loan_status'): presenti in 2 person_home_ownership -> person_home_ownership name: RENT, person_home_ownership name: OTHER
#
#
# ---------------------
#
#
# Correlazioni presenti in 2 o più loan_intent:
# ('cb_person_cred_hist_length', 'person_age'): presenti in 6 loan_intent -> loan_intent name: VENTURE, loan_intent name: EDUCATION, loan_intent name: PERSONAL, loan_intent name: MEDICAL, loan_intent name: DEBTCONSOLIDATION, loan_intent name: HOMEIMPROVEMENT
# ('loan_amnt', 'loan_percent_income'): presenti in 6 loan_intent -> loan_intent name: VENTURE, loan_intent name: EDUCATION, loan_intent name: PERSONAL, loan_intent name: MEDICAL, loan_intent name: DEBTCONSOLIDATION, loan_intent name: HOMEIMPROVEMENT
# ('loan_percent_income', 'loan_status'): presenti in 5 loan_intent -> loan_intent name: VENTURE, loan_intent name: EDUCATION, loan_intent name: PERSONAL, loan_intent name: MEDICAL, loan_intent name: DEBTCONSOLIDATION
# ('loan_amnt', 'person_income'): presenti in 3 loan_intent -> loan_intent name: PERSONAL, loan_intent name: MEDICAL, loan_intent name: HOMEIMPROVEMENT
# ('loan_int_rate', 'loan_status'): presenti in 3 loan_intent -> loan_intent name: DEBTCONSOLIDATION, loan_intent name: MEDICAL, loan_intent name: HOMEIMPROVEMENT
#
#
# ---------------------
#
#
# Correlazioni presenti in 2 o più loan_grade:
# ('cb_person_cred_hist_length', 'person_age'): presenti in 7 loan_grade -> loan_grade name: G, loan_grade name: E, loan_grade name: D, loan_grade name: F, loan_grade name: B, loan_grade name: A, loan_grade name: C
# ('loan_amnt', 'person_income'): presenti in 6 loan_grade -> loan_grade name: G, loan_grade name: E, loan_grade name: D, loan_grade name: F, loan_grade name: B, loan_grade name: C
# ('loan_amnt', 'loan_percent_income'): presenti in 7 loan_grade -> loan_grade name: G, loan_grade name: E, loan_grade name: D, loan_grade name: F, loan_grade name: B, loan_grade name: A, loan_grade name: C
# ('loan_percent_income', 'loan_status'): presenti in 3 loan_grade -> loan_grade name: A, loan_grade name: C, loan_grade name: B
# ('loan_percent_income', 'person_income'): presenti in 4 loan_grade -> loan_grade name: G, loan_grade name: A, loan_grade name: E, loan_grade name: F
# ('loan_status', 'person_income'): presenti in 3 loan_grade -> loan_grade name: G, loan_grade name: E, loan_grade name: F
# ('loan_status', 'person_emp_length'): presenti in 2 loan_grade -> loan_grade name: E, loan_grade name: F
#
#
# ---------------------
#
#
# Correlazioni presenti in 2 o più cb_person_default_on_file:
# ('cb_person_cred_hist_length', 'person_age'): presenti in 2 cb_person_default_on_file -> cb_person_default_on_file name: Y, cb_person_default_on_file name: N
# ('loan_amnt', 'person_income'): presenti in 2 cb_person_default_on_file -> cb_person_default_on_file name: Y, cb_person_default_on_file name: N
# ('loan_amnt', 'loan_percent_income'): presenti in 2 cb_person_default_on_file -> cb_person_default_on_file name: Y, cb_person_default_on_file name: N
# ('loan_percent_income', 'loan_status'): presenti in 2 cb_person_default_on_file -> cb_person_default_on_file name: Y, cb_person_default_on_file name: N

# %%
df.columns
# Out:
# Index(['id', 'person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_default_on_file',
#        'cb_person_cred_hist_length', 'loan_status'],
#       dtype='object')

# %%
df['cut_età'] = pd.cut(df['person_age'], bins=[20, 30, 40, 50, 60, 80, 125], labels=['giovanissimo', 'giovane', 'young_adulto', 'adulto','anziano','vecchio'])

# %%
sns.violinplot(data=df[df["loan_amnt"] < 25000], y='cut_età', x='loan_amnt')
plt.title("Violinplot")
plt.show()

# %%
sns.barplot(data=df, x='cut_età', y='person_income')
plt.title('Personal Income a seconda dei gruppi di età')
plt.show()

# %%
sns.kdeplot(data=df, x='person_age', fill=True)
plt.title("Stima della Densità dell'età")
plt.show()

# %%
sns.countplot(data=df, x='cut_età', hue='loan_intent')
plt.title('Motivazioni prestito a seconda delle età')
plt.show()
